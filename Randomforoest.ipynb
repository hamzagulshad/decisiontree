# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzagulshad/decisiontree/blob/main/Randomforoest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('/content/heart_failure_clinical_records.csv')
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
#x=pd.get_dummies(x) #encoded catogorical features
data["DEATH_EVENT"]=data['DEATH_EVENT'].astype('category').cat.codes
data["high_blood_pressure"]=data['high_blood_pressure'].astype('category').cat.codes

# %%
#split the data int training and test
x=data.drop(columns="DEATH_EVENT")
y=data["DEATH_EVENT"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=70)

# %%
rf=RandomForestRegressor(n_estimators=100,random_state=1)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
#print("Accuracy score =",accuracy_score(y_test,y_pred))

# %%
print(data['DEATH_EVENT'].unique())
# Out:
# [1 0]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
#print("Accuracy score =",accuracy_score(y_test,y_pred))
print("r2_score error =",r2_score(y_test,y_pred))
print("mean_absolute_error = ",mean_absolute_error (y_test,y_pred))
print("mean_squared_error =",mean_squared_error (y_test,y_pred))
# Out:
# r2_score error = 0.551255980861244
# mean_absolute_error =  0.21283333333333335
# mean_squared_error = 0.10420833333333332

# %%
#Randomfores classifiers

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('/content/heart_failure_clinical_records.csv')
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data["DEATH_EVENT"]=data['DEATH_EVENT'].astype('category').cat.codes
data["high_blood_pressure"]=data['high_blood_pressure'].astype('category').cat.codes
data["diabetes"]=data['diabetes'].astype('category').cat.codes

# %%
#split the data int training and test
x=data.drop(columns="diabetes")
y=data["diabetes"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=70)

# %%
rf=RandomForestClassifier(n_estimators=100,random_state=1)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print("Accuracy score =",accuracy_score(y_test,y_pred))
print("r2_score error =",r2_score(y_test,y_pred))
print("mean_absolute_error = ",mean_absolute_error (y_test,y_pred))
print("mean_squared_error =",mean_squared_error (y_test,y_pred))
# Out:
# Accuracy score = 0.6166666666666667
# r2_score error = -0.5350389321468298
# mean_absolute_error =  0.38333333333333336
# mean_squared_error = 0.38333333333333336
